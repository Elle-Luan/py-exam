# %% [markdown]
# # 基础题 1（10分）
# 编写一个迎宾机器人，在客人进门时对每一位客人说：Hello。传入的是一个客人
#
# 名字的列表，输出格式为："Hello，xxx. Hello，xxx...."

# %%
# 考生无需编辑
guests = ["Mr.Green", "Mr.Black", "Mr.White"]
your_message = ""

# %%
# 在下一行输入你的代码，将需要打印的内容写入your_message

# %%
# 你应该打印以下结果
# Hello, Mr.Green. Hello, Mr.Black. Hello, Mr.White.
print(your_message)
# Out:
# Hello, Mr.Green. Hello, Mr.Black. Hello, Mr.White.

# %% [markdown]
# # 基础题 2 (15分)
# 编写程序计算输入的n个成绩中最高分和最低分的差值。
# - 输入：一个由若干成绩组成的列表（范围0~100）
# - 输出：最高分与最低分的差值

# %%
# 预设输入成绩字符串（考生无需编辑）
score_list = [85, 92, 78, 98, 88, 65, 90]
# 存储最终计算结果（考生无需编辑）
score_diff = 0

# %%
# 在下一行输入你的代码，计算成绩差值并赋值给score_diff
# 步骤提示：分割字符串→转换为整数列表→排序→计算首尾差值

# %%
# 你应该打印以下结果（以预设输入为例，正确结果应为33）
# 33
print(score_diff)
# Out:
# 33

# %% [markdown]
# # 基础题 3 (15分)
# 编写程序完成对指定字典的修改与扩展：
# - 已知字典`data = {'python': 90, 'c++': 95, 'java': 90}`；
# - 要求1：将`python`键对应的值修改为100；
# - 要求2：新增键值对`'php': 92`；
# - 输出：修改后的完整字典。

# %%
# 预设初始字典（考生无需编辑）
data = {
    'python': 90,
    'c++': 95,
    'java': 90
}

# %%
# 在下一行输入你的代码，完成字典的修改与新增操作
# 步骤提示：修改python对应的值 → 新增php键值对

# %%
# 你应该打印以下结果：
# {'python': 100, 'c++': 95, 'java': 90, 'php': 92}
print(data)
# Out:
# {'python': 100, 'c++': 95, 'java': 90, 'php': 92}

# %% [markdown]
# # 基础题 4 (20分)
# 编写成绩等级转换程序，规则如下：
# - 60分以下：不合格
# - 60~69分：合格
# - 70~89分：良好
# - 90~100分：优秀
# - 输入数据超出0~100范围：提示“错误数据”
#
# 要求：输入一个百分制成绩（整数），输出对应的等级或错误提示。

# %%
# 初始化结果变量（考生无需编辑）
grade = ""
# 获取用户输入（考生无需编辑）
try:
    score = int(input('请输入成绩：'))
except ValueError:
    # 处理非数字输入的情况
    grade = "错误数据"
# Out:
# 请输入成绩： 85

# %%
# 在下一行输入你的代码，根据score计算等级并赋值给grade
# 步骤提示：判断score范围 → 赋值对应等级；非0~100则赋值“错误数据”

# %%
# 示例输入85，应输出“良好”；输入105，输出“错误数据”；输入abc，输出“错误数据”
print(grade)
# Out:
# 良好

# %% [markdown]
# # 基础题 5 (20分)
# 列表`universities`中存储了39所985高校的信息，每个元素是包含“名称”和“类型”的字典。
# 请完善Python代码，统计并输出各类型高校的数量。
# - 输入：无（使用预设的`universities`列表）
# - 输出：按格式打印各类型高校的数量（如：综合:20）

# %%
# 预设高校信息列表（每个元素为字典，包含名称和类型，考生无需编辑）
universities = [
    {"name": "北京大学", "type": "综合"},
    {"name": "清华大学", "type": "理工"},
    {"name": "复旦大学", "type": "综合"},
    {"name": "上海交通大学", "type": "综合"},
    {"name": "南京大学", "type": "综合"},
    {"name": "浙江大学", "type": "综合"},
    {"name": "中国科学技术大学", "type": "综合"},
    {"name": "哈尔滨工业大学", "type": "理工"},
    {"name": "西安交通大学", "type": "综合"},
    {"name": "北京理工大学", "type": "理工"},
    {"name": "北京师范大学", "type": "师范"},
    {"name": "南开大学", "type": "综合"},
    {"name": "天津大学", "type": "理工"},
    {"name": "东南大学", "type": "综合"},
    {"name": "华中科技大学", "type": "理工"},
    {"name": "武汉大学", "type": "综合"},
    {"name": "厦门大学", "type": "综合"},
    {"name": "山东大学", "type": "综合"},
    {"name": "中国人民大学", "type": "综合"},
    {"name": "吉林大学", "type": "综合"},
    {"name": "大连理工大学", "type": "理工"},
    {"name": "同济大学", "type": "理工"},
    {"name": "华南理工大学", "type": "理工"},
    {"name": "中南大学", "type": "理工"},
    {"name": "华东师范大学", "type": "师范"},
    {"name": "中山大学", "type": "综合"},
    {"name": "中国农业大学", "type": "农林"},
    {"name": "西北工业大学", "type": "理工"},
    {"name": "湖南大学", "type": "综合"},
    {"name": "东北大学", "type": "理工"},
    {"name": "重庆大学", "type": "理工"},
    {"name": "电子科技大学", "type": "理工"},
    {"name": "四川大学", "type": "综合"},
    {"name": "北京航空航天大学", "type": "理工"},
    {"name": "兰州大学", "type": "综合"},
    {"name": "西北农林科技大学", "type": "农林"},
    {"name": "中央民族大学", "type": "民族"},
    {"name": "国防科技大学", "type": "军事"},
    {"name": "中国海洋大学", "type": "综合"}
]
# 初始化统计字典（考生无需编辑）
type_count = {}

# %%
# 在下一行输入你的代码，统计各类型高校数量并赋值给type_count
# 步骤提示：遍历universities列表 → 提取每个字典的"type"值 → 统计数量

# %%
# 按格式输出统计结果（应输出：综合:20 理工:13 师范:2 农林:2 民族:1 军事:1）
for t, count in type_count.items():
    print(f"{t}:{count}")
# Out:
# 综合:19
# 理工:14
# 师范:2
# 农林:2
# 民族:1
# 军事:1
